# %%
import pandas as pd
df = pd.read_csv('Stock_list.csv', delimiter=',')
df.head()
# Out:
#   Industry                  Name Symbol Exchange
# 0   Energy            ExxonMobil    XOM     NYSE
# 1   Energy               Chevron    CVX     NYSE
# 2   Energy           First Solar   FSLR   NASDAQ
# 3   Energy  Occidental Petroleum    OXY     NYSE
# 4   Energy         Kinder Morgan    KMI     NYSE

# %%
#Reorder frame
Stocks_df=df[['Symbol','Name','Industry','Exchange']]
Stocks_df.reset_index()
Stocks_df
# Out:
#    Symbol                    Name                Industry Exchange
# 0     XOM              ExxonMobil                  Energy     NYSE
# 1     CVX                 Chevron                  Energy     NYSE
# 2    FSLR             First Solar                  Energy   NASDAQ
# 3     OXY    Occidental Petroleum                  Energy     NYSE
# 4     KMI           Kinder Morgan                  Energy     NYSE
# 5     DUK             Duke Energy                  Energy     NYSE
# 6     XEL             Xcel Energy                  Energy   NASDAQ
# 7     LNG         Cheniere Energy                  Energy     NYSE
# 8     COP          ConocoPhillips                  Energy     NYSE
# 9     ENB                Enbridge                  Energy     NYSE
# 10    NKE                    Nike                  Retail     NYSE
# 11    MCD              McDonald's                  Retail     NYSE
# 12    DIS                  Disney                  Retail     NYSE
# ...

# %%
Stocks_df.to_json(r'C:\Users\eveba\Bootcamp\20-Project-2\Project-02\static\json\stocks.json', orient='split')

# %%
Industry_df=df[['Industry','Symbol','Name','Exchange']]
Industry_df.reset_index()
Industry_df
# Out:
#                   Industry Symbol                    Name Exchange
# 0                   Energy    XOM              ExxonMobil     NYSE
# 1                   Energy    CVX                 Chevron     NYSE
# 2                   Energy   FSLR             First Solar   NASDAQ
# 3                   Energy    OXY    Occidental Petroleum     NYSE
# 4                   Energy    KMI           Kinder Morgan     NYSE
# 5                   Energy    DUK             Duke Energy     NYSE
# 6                   Energy    XEL             Xcel Energy   NASDAQ
# 7                   Energy    LNG         Cheniere Energy     NYSE
# 8                   Energy    COP          ConocoPhillips     NYSE
# 9                   Energy    ENB                Enbridge     NYSE
# 10                  Retail    NKE                    Nike     NYSE
# 11                  Retail    MCD              McDonald's     NYSE
# 12                  Retail    DIS                  Disney     NYSE
# ...

# %%
Industry_df.to_json(r'C:\Users\eveba\Bootcamp\20-Project-2\Project-02\static\json\Industry.json', orient='split')

# %%
Exchange_df=df[['Exchange','Symbol','Name','Industry']]
Exchange_df.sort_values('Exchange')
# Out:
#    Exchange Symbol                    Name                Industry
# 24   NASDAQ   NVAX                 Novavax              Healthcare
# 27   NASDAQ    AZN            Astrazeneca               Healthcare
# 26   NASDAQ   MRNA                Moderna               Healthcare
# 48   NASDAQ   QCOM                Qualcomm  Information Technology
# 21   NASDAQ   ISRG      Intuitive Surgical              Healthcare
# 20   NASDAQ   VRTX  Vertex Pharmaceuticals              Healthcare
# 17   NASDAQ   COST        Costco Wholesale                  Retail
# 16   NASDAQ    PEP                 PepsiCo                  Retail
# 13   NASDAQ   SBUX               Starbucks                  Retail
# 40   NASDAQ  GOOGL                  Google  Information Technology
# 14   NASDAQ   AMZN                  Amazon                  Retail
# 2    NASDAQ   FSLR             First Solar                  Energy
# 43   NASDAQ     FB                Facebook  Information Technology
# ...

# %%
Exchange_df.to_json(r'C:\Users\eveba\Bootcamp\20-Project-2\Project-02\static\json\exchange.json', orient='split')
